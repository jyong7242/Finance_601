# %% [markdown]
# # 2024 MFIN 602 Team Project
#
# Here is list of tasks:
# Construct a portfolio of stocks in the Energy sector/industry and government bonds.
# Collect financial data of the companies in the Energy sector/industry. See the list of names on the references Excel sheet. Use Refinitiv or Bloomberg to collect data.
#
# ## PART A.
# Choose 5-to-10 stocks for your portfolio according to their “Valuation” and “Price Momentum”.
# 1.	Explain what measures of “Valuation” and “Momentum” do you use and why.
# 2.	Which stocks do you choose? Explain the reasoning and method.
# 3.	What are the weights of stocks? How do you decide?

# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
import itertools
file_path = 'data/temp_602_data.xlsx'
df_header = pd.read_excel(file_path,header=0)
df = pd.read_excel(file_path,header=1)
df.head()
# Out:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  54.4262              13.1222        12.20
# 1 2023-11-01  61.6514              13.6700        12.34
# 2 2023-11-02  67.4024              14.2077        12.64
# 3 2023-11-03  66.3652              14.6169        12.95
# 4 2023-11-06  64.5814              15.1469        12.92
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO  RSI_14D.1  REL_SHR_PX_MOMENTUM.1  \
# 0                    11.3908   16.7498    50.1156                22.5592
# 1                    11.5694   17.1570    60.3212                23.1530
# 2                    11.7540   17.5777    68.4889                23.8276
# 3                    11.7361   17.5370    73.2355                24.7095
# 4                    11.7064   17.4692    66.2905                25.7792
#
#    PX_CLOSE_1D.1  CURRENT_EV_TO_T12M_EBITDA.1  ...  RSI_14D.30  \
# 0          12.58                       9.2570  ...     43.2394
# 1          12.67                       9.4623  ...     46.0134
# 2          13.18                       9.6881  ...     66.1428
# 3          13.78                       9.8807  ...     58.0093
# 4          14.26                       9.7563  ...     55.9903
#
#    REL_SHR_PX_MOMENTUM.30  PX_CLOSE_1D.30  CURRENT_EV_TO_T12M_EBITDA.30  \
# 0                  8.7538           83.60                        8.6212
# 1                  9.1463           83.61                        8.6524
# 2                  9.8181           84.15                        8.9876
# 3                 10.2280           90.25                        8.8650
# 4                 11.4343           88.12                        8.8316
#
#    PE_RATIO.30  RSI_14D.31  REL_SHR_PX_MOMENTUM.31  PX_CLOSE_1D.31  \
# 0      20.2732     35.8832                 16.9063           26.09
# 1      20.4041     35.0637                 16.7608           26.14
# 2      21.8832     61.7304                 16.9874           26.05
# 3      21.3668     66.8476                 17.4230           28.60
# 4      21.2261     57.9415                 18.0486           29.49
#
#    CURRENT_EV_TO_T12M_EBITDA.31  PE_RATIO.31
# 0                        9.7094      77.0548
# 1                        9.6913      77.0548
# 2                       10.2188      77.0548
# 3                       10.3983      77.0548
# 4                       10.2067      77.0548
#
# [5 rows x 161 columns]

# %% [markdown]
# ## Preprocessing Data
# After parsing data from Bloomberg, we gain one Excel file.
# We first need to preprocess the data to make it easier to work with.
# 1. Drop columns with all missing values, such as NaN or unrealistic values from the excel file. (Done in Excel)
# 2. Create data frames for each stock for easier manipulation.

# %%
# Create a dictionary to store all DataFrame
dfs = {}
# Get stock names
stock_names = df_header.columns[1::5].str.replace(" ", "_")
#check stock_names
print(stock_names)
# Out:
# Index(['AM_US_Equity', 'AROC_US_Equity', 'BOOM_US_Equity', 'CEIX_US_Equity',
#        'CHX_US_Equity', 'CIVI_US_Equity', 'CLB_US_Equity', 'CNX_US_Equity',
#        'CPE_US_Equity', 'DTM_US_Equity', 'ETRN_US_Equity', 'HLX_US_Equity',
#        'HP_US_Equity', 'LPG_US_Equity', 'MTDR_US_Equity', 'MUR_US_Equity',
#        'NOV_US_Equity', 'OII_US_Equity', 'OIS_US_Equity', 'PARR_US_Equity',
#        'PBF_US_Equity', 'PTEN_US_Equity', 'PUMP_US_Equity', 'RES_US_Equity',
#        'REX_US_Equity', 'RRC_US_Equity', 'SLCA_US_Equity', 'SM_US_Equity',
#        'SWN_US_Equity', 'TALO_US_Equity', 'TRGP_US_Equity', 'VTOL_US_Equity'],
#       dtype='object')

# %%
# Go through the stock name and create their own DataFrame
for i, stock_name in enumerate(stock_names):
    cols = ['Dates'] + list(df.columns[i*5 + 1:i*5 + 6])
    stock_df = df[cols].copy() 
    stock_df.columns = ['Dates', 'RSI_14D', 'REL_SHR_PX_MOMENTUM', 'PX_CLOSE_1D', 'CURRENT_EV_TO_T12M_EBITDA', 'PE_RATIO']
    # save the DataFrame to the dictionary
    dfs[f"{stock_name}_df"] = stock_df

    
# Check DataFrames
# for name, stock_df in dfs.items():
#     print(f"DataFrame for {name}:")
#     display(stock_df.head())

# %% [markdown]
# ## Explain what measures of “Valuation” and “Momentum” do you use and why.
# We will use the following indicators to evaluate the valuation and momentum of each stock:
# 1. **Valuation**:
#     - **Price-to-Earnings (P/E) Ratio**: The P/E ratio is a measure of a company's valuation. It indicates how much investors are willing to pay for each dollar of earnings. A lower P/E ratio may indicate that a stock is undervalued.
#     - **EV/EBITDA Ratio**: The EV/EBITDA ratio is another valuation metric that compares a company's enterprise value to its earnings before interest, taxes, depreciation, and amortization. A lower EV/EBITDA ratio may indicate that a stock is undervalued.
# 2. **Momentum**:
#     - **Relative Share Price Momentum**: The relative share price momentum measures the price momentum of a stock relative to the overall market. A positive relative share price momentum indicates that a stock is outperforming the market.
#     - **RSI (Relative Strength Index)**: The RSI is a momentum oscillator that measures the speed and change of price movements. It ranges from 0 to 100 and is typically used to identify overbought or oversold conditions in a stock.
# ## Which stocks do you choose? Explain the reasoning and method.
# We will choose the top 5 stocks based on the average ranking of the following indicators:
# 1. **RSI_14D**: The average 14-day RSI value.
# 2. **REL_SHR_PX_MOMENTUM**: The average relative share price momentum.
# 3. **CURRENT_EV_TO_T12M_EBITDA**: The average current enterprise value to trailing twelve months EBITDA ratio.
# 4. **PE_RATIO**: The average price-to-earnings ratio.
# 5. **TOTAL_RANK**: The sum of the rankings of the above four indicators.
# 6. **RETURNS**: The daily returns of each stock based on the closing price.
# 7. **Correlation Matrix**: The correlation matrix of the daily returns of each stock.
# ### Method:
# We will calculate the average value of each indicator for each stock and rank the stocks based on these averages. The lower the average rank, the higher the stock's position in the final selection. We pick the top 10 stocks based on the total rank and use volatility and Sharpe ratio optimization to select the best combination of stocks.

# %%
# Initialize an empty DataFrame to store the ranking information
rank_df = pd.DataFrame()

# Go through each stock DataFrame and calculate the average values of the indicators
for name, stock_df in dfs.items():
    stock_name = name.replace("_df", "")  # 去掉后缀以得到股票名称

    # Calculate the average values of the indicators
    rsi_avg = stock_df['RSI_14D'].mean()
    momentum_avg = stock_df['REL_SHR_PX_MOMENTUM'].mean()
    ev_to_ebitda_avg = stock_df['CURRENT_EV_TO_T12M_EBITDA'].mean()
    pe_ratio_avg = stock_df['PE_RATIO'].mean()

    # 创建一个包含当前股票的平均值排名信息的 DataFrame
    rank_info = pd.DataFrame({
        "RSI_14D_AVG": [rsi_avg],
        "REL_SHR_PX_MOMENTUM_AVG": [momentum_avg],
        "CURRENT_EV_TO_T12M_EBITDA_AVG": [ev_to_ebitda_avg],
        "PE_RATIO_AVG": [pe_ratio_avg]
    }, index=[stock_name])

    # 使用 pd.concat 将当前股票的排名信息添加到 rank_df
    rank_df = pd.concat([rank_df, rank_info])

# 计算排名
rank_df["RSI_14D_RANK"] = rank_df["RSI_14D_AVG"].rank(ascending=True)
rank_df["REL_SHR_PX_MOMENTUM_RANK"] = rank_df["REL_SHR_PX_MOMENTUM_AVG"].rank(ascending=False)
rank_df["CURRENT_EV_TO_T12M_EBITDA_RANK"] = rank_df["CURRENT_EV_TO_T12M_EBITDA_AVG"].rank(ascending=True)
rank_df["PE_RATIO_RANK"] = rank_df["PE_RATIO_AVG"].rank(ascending=True)

# 计算总排名
rank_df["TOTAL_RANK"] = (
    rank_df["RSI_14D_RANK"]
    + rank_df["REL_SHR_PX_MOMENTUM_RANK"]
    + rank_df["CURRENT_EV_TO_T12M_EBITDA_RANK"]
    + rank_df["PE_RATIO_RANK"]
)

# 按 TOTAL_RANK 从低到高排序
rank_df = rank_df.sort_values(by="TOTAL_RANK", ascending=True)

# 显示结果
rank_df.reset_index(inplace=True)
rank_df.rename(columns={'index': 'Stock'}, inplace=True)
display(rank_df)
# Out:
#              Stock  RSI_14D_AVG  REL_SHR_PX_MOMENTUM_AVG  \
# 0   PARR_US_Equity    44.085725               -12.483676
# 1    PBF_US_Equity    45.360784               -11.347326
# 2    MUR_US_Equity    45.321266               -11.170992
# 3   CEIX_US_Equity    50.828905                 6.211615
# 4    LPG_US_Equity    50.620866                14.384045
# 5     SM_US_Equity    51.593378                 4.869292
# 6   CIVI_US_Equity    45.664069               -15.477718
# 7   MTDR_US_Equity    48.753570                -6.402370
# 8    RES_US_Equity    46.109671               -18.035006
# 9     HP_US_Equity    47.518555               -12.799495
# 10  PUMP_US_Equity    46.796553                -9.908327
# 11  SLCA_US_Equity    55.113707                 1.385665
# 12   CNX_US_Equity    55.749972                 7.237958
# 13   REX_US_Equity    50.494538                 5.438140
# 14  TALO_US_Equity    45.852968               -19.772621
# 15   NOV_US_Equity    47.521642                -9.933644
# 16  BOOM_US_Equity    44.656575               -25.827202
# 17  PTEN_US_Equity    44.292035               -21.444129
# 18   CPE_US_Equity    56.506477               -20.685181
# 19  ETRN_US_Equity    50.697798                13.376021
# 20   HLX_US_Equity    50.134509                 2.842673
# 21   RRC_US_Equity    49.430967                -5.441597
# 22   SWN_US_Equity    51.671686                -2.963441
# 23   CHX_US_Equity    48.395489                -9.343353
# 24  AROC_US_Equity    56.477186                20.410870
# 25  TRGP_US_Equity    61.648032                16.633652
# 26   OII_US_Equity    50.795253                -0.938635
# 27   DTM_US_Equity    60.559537                 7.189550
# 28   OIS_US_Equity    45.402087               -28.364634
# 29    AM_US_Equity    54.484153                 1.272426
# 30  VTOL_US_Equity    52.093479                 2.814441
# 31   CLB_US_Equity    48.621519               -16.273861
#
#     CURRENT_EV_TO_T12M_EBITDA_AVG  PE_RATIO_AVG  RSI_14D_RANK  \
# 0                        3.555707      3.937278           1.0
# 1                        3.440704      4.675697           5.0
# 2                        3.090731      9.174420           4.0
# 3                        3.187602      5.933504          22.0
# 4                        5.648236      5.466480          19.0
# 5                        3.664888      6.959050          23.0
# 6                        3.860826      6.734961           7.0
# 7                        4.724851      8.318373          15.0
# 8                        4.102745      9.821130           9.0
# 9                        4.430170     10.384907          11.0
# 10                       4.912682     12.977239          10.0
# 11                       4.433828      9.613694          27.0
# 12                       3.452946     17.891794          28.0
# 13                       6.000981     13.478563          18.0
# 14                       3.372916     20.001645           8.0
# 15                       8.824008      8.303236          12.0
# 16                       5.797488     11.125166           3.0
# 17                       5.379986     15.634352           2.0
# 18                       4.683321      4.412650          30.0
# 19                      13.473841     13.543413          20.0
# 20                       5.641911     39.857277          17.0
# 21                       7.459776     15.012626          16.0
# 22                       6.597811     12.431236          24.0
# 23                       8.509441     18.532467          13.0
# 24                      10.443375     23.884009          29.0
# 25                      10.625042     24.993514          32.0
# 26                       9.498919     29.644527          21.0
# 27                      14.295505     16.637583          31.0
# 28                       6.809692     62.708192           6.0
# 29                      12.750752     17.467148          26.0
# 30                       8.719195     92.955725          25.0
# 31                      11.852741     27.086121          14.0
#
#     REL_SHR_PX_MOMENTUM_RANK  CURRENT_EV_TO_T12M_EBITDA_RANK  PE_RATIO_RANK  \
# 0                       23.0                             6.0            1.0
# 1                       22.0                             4.0            3.0
# 2                       21.0                             1.0           10.0
# 3                        7.0                             2.0            5.0
# 4                        3.0                            17.0            4.0
# 5                        9.0                             7.0            7.0
# 6                       25.0                             8.0            6.0
# 7                       17.0                            13.0            9.0
# 8                       27.0                             9.0           12.0
# 9                       24.0                            10.0           13.0
# 10                      19.0                            14.0           16.0
# 11                      12.0                            11.0           11.0
# 12                       5.0                             5.0           23.0
# 13                       8.0                            19.0           17.0
# 14                      28.0                             3.0           25.0
# 15                      20.0                            25.0            8.0
# 16                      31.0                            18.0           14.0
# 17                      30.0                            15.0           20.0
# 18                      29.0                            12.0            2.0
# 19                       4.0                            31.0           18.0
# 20                      10.0                            16.0           30.0
# 21                      16.0                            22.0           19.0
# 22                      15.0                            20.0           15.0
# 23                      18.0                            23.0           24.0
# 24                       1.0                            27.0           26.0
# 25                       2.0                            28.0           27.0
# 26                      14.0                            26.0           29.0
# 27                       6.0                            32.0           21.0
# 28                      32.0                            21.0           31.0
# 29                      13.0                            30.0           22.0
# 30                      11.0                            24.0           32.0
# 31                      26.0                            29.0           28.0
#
#     TOTAL_RANK
# 0         31.0
# 1         34.0
# 2         36.0
# 3         36.0
# 4         43.0
# 5         46.0
# 6         46.0
# 7         54.0
# 8         57.0
# 9         58.0
# 10        59.0
# 11        61.0
# 12        61.0
# 13        62.0
# 14        64.0
# 15        65.0
# 16        66.0
# 17        67.0
# 18        73.0
# 19        73.0
# 20        73.0
# 21        73.0
# 22        74.0
# 23        78.0
# 24        83.0
# 25        89.0
# 26        90.0
# 27        90.0
# 28        90.0
# 29        91.0
# 30        92.0
# 31        97.0

# %% [markdown]
# ## Calculate Returns for each stock
# We will calculate the daily returns for each stock using the 'PX_CLOSE_1D' column.

# %%
for name, stock_df in dfs.items():
    stock_df['RETURNS'] = stock_df['PX_CLOSE_1D'].pct_change().fillna(0)

# Check RETURNS DataFrame
for name, stock_df in dfs.items():
    print(f"DataFrame for {name} with RETURNS:")
    display(stock_df.head())
# Out:
# DataFrame for AM_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  54.4262              13.1222        12.20
# 1 2023-11-01  61.6514              13.6700        12.34
# 2 2023-11-02  67.4024              14.2077        12.64
# 3 2023-11-03  66.3652              14.6169        12.95
# 4 2023-11-06  64.5814              15.1469        12.92
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                    11.3908   16.7498  0.000000
# 1                    11.5694   17.1570  0.011475
# 2                    11.7540   17.5777  0.024311
# 3                    11.7361   17.5370  0.024525
# 4                    11.7064   17.4692 -0.002317
# DataFrame for AROC_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  50.1156              22.5592        12.58
# 1 2023-11-01  60.3212              23.1530        12.67
# 2 2023-11-02  68.4889              23.8276        13.18
# 3 2023-11-03  73.2355              24.7095        13.78
# 4 2023-11-06  66.2905              25.7792        14.26
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     9.2570   24.0164  0.000000
# 1                     9.4623   24.9831  0.007154
# 2                     9.6881   26.1204  0.040253
# 3                     9.8807   27.0303  0.045524
# 4                     9.7563   26.4426  0.034833
# DataFrame for BOOM_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  27.3440               2.9762        18.82
# 1 2023-11-01  26.3480               2.3356        18.95
# 2 2023-11-02  29.7907               1.9457        18.79
# 3 2023-11-03  20.1875               0.7083        18.99
# 4 2023-11-06  19.1332               0.0545        17.10
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     6.2825    9.5421  0.000000
# 1                     6.2538    9.4615  0.006908
# 2                     6.2892    9.5622 -0.008443
# 3                     5.9503    8.6105  0.010644
# 4                     5.8966    8.4595 -0.099526
# DataFrame for CEIX_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  35.3042              66.4999       102.17
# 1 2023-11-01  43.2485              66.0444        91.89
# 2 2023-11-02  45.5889              65.3920        96.44
# 3 2023-11-03  45.4525              65.2470        97.92
# 4 2023-11-06  43.2507              63.9978        97.82
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     2.5532    4.7143  0.000000
# 1                     2.6809    4.9477 -0.100617
# 2                     2.7225    5.0237  0.049516
# 3                     2.7196    5.0185  0.015346
# 4                     2.6753    4.9375 -0.001021
# DataFrame for CHX_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  33.6253              17.0894        30.47
# 1 2023-11-01  31.5422              16.5913        30.80
# 2 2023-11-02  39.5327              15.9891        30.28
# 3 2023-11-03  39.4364              15.5259        31.31
# 4 2023-11-06  34.3086              15.1319        31.29
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     9.1757   18.3281  0.000000
# 1                     9.0299   18.0187  0.010830
# 2                     9.3188   18.6316 -0.016883
# 3                     9.3132   18.6197  0.034016
# 4                     8.9934   17.9413 -0.000639
# DataFrame for CIVI_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31
US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  30.1484               1.2330        12.29
# 1 2023-11-01  28.4759               0.9066        12.07
# 2 2023-11-02  34.3584               0.3207        11.93
# 3 2023-11-03  31.8093              -0.0439        12.14
# 4 2023-11-06  28.3518              -0.7553        11.95
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     3.6698    5.9290  0.000000
# 1                     3.6460    5.8603 -0.017901
# 2                     3.6818    5.9634 -0.011599
# 3                     3.6504    5.8701  0.017603
# 4                     3.6010    5.7276 -0.015651
# DataFrame for SM_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  49.0333              36.7529        39.82
# 1 2023-11-01  45.1177              37.8463        40.32
# 2 2023-11-02  53.4453              38.9949        39.57
# 3 2023-11-03  49.9893              39.4876        41.13
# 4 2023-11-06  43.2375              41.7235        40.47
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     3.5998    7.2395  0.000000
# 1                     3.5461    7.1048  0.012557
# 2                     3.6579    7.3849 -0.018601
# 3                     3.5531    7.2664  0.039424
# 4                     3.4491    7.0007 -0.016047
# DataFrame for SWN_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  60.9369              30.5783         7.06
# 1 2023-11-01  61.8097              32.0992         7.13
# 2 2023-11-02  67.0890              33.3991         7.16
# 3 2023-11-03  71.1668              34.5640         7.36
# 4 2023-11-06  52.3992              36.6572         7.55
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     2.5958    9.3970  0.000000
# 1                     2.6028    9.4365  0.009915
# 2                     2.6501    9.7001  0.004208
# 3                     2.6950    9.9505  0.027933
# 4                     2.5745    9.2783  0.025815
# DataFrame for TALO_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  44.5258               8.1707        15.33
# 1 2023-11-01  39.0238               8.8079        15.50
# 2 2023-11-02  47.6553               9.3080        15.04
# 3 2023-11-03  45.8172               9.3666        15.61
# 4 2023-11-06  37.1711              11.6165        15.46
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     3.2871   18.9736  0.000000
# 1                     3.2273   18.4105  0.011089
# 2                     3.3014   19.1082 -0.029677
# 3                     3.2819   18.9246  0.037899
# 4                     3.1726   17.8964 -0.009609
# DataFrame for TRGP_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  43.2394               8.7538        83.60
# 1 2023-11-01  46.0134               9.1463        83.61
# 2 2023-11-02  66.1428               9.8181        84.15
# 3 2023-11-03  58.0093              10.2280        90.25
# 4 2023-11-06  55.9903              11.4343        88.12
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     8.6212   20.2732  0.000000
# 1                     8.6524   20.4041  0.000120
# 2                     8.9876   21.8832  0.006459
# 3                     8.8650   21.3668  0.072490
# 4                     8.8316   21.2261 -0.023601
# DataFrame for VTOL_US_Equity_df with RETURNS:
#        Dates  RSI_14D  REL_SHR_PX_MOMENTUM  PX_CLOSE_1D  \
# 0 2023-10-31  35.8832              16.9063        26.09
# 1 2023-11-01  35.0637              16.7608        26.14
# 2 2023-11-02  61.7304              16.9874        26.05
# 3 2023-11-03  66.8476              17.4230        28.60
# 4 2023-11-06  57.9415              18.0486        29.49
#
#    CURRENT_EV_TO_T12M_EBITDA  PE_RATIO   RETURNS
# 0                     9.7094   77.0548  0.000000
# 1                     9.6913   77.0548  0.001916
# 2                    10.2188   77.0548 -0.003443
# 3                    10.3983   77.0548  0.097889
# 4                    10.2067   77.0548  0.031119

# %%
# 创建一个新的 DataFrame 来存储所有股票的 'RETURNS' 列
returns_df = pd.DataFrame()
sample_stock = next(iter(dfs.values()))
returns_df['Dates'] = sample_stock['Dates'].values

# 将每个股票的 'RETURNS' 列添加到 returns_df 中
for name, stock_df in dfs.items():
    stock_name = name.replace("_df", "")  # 去掉后缀，得到股票名称
    returns_df[stock_name] = stock_df['RETURNS']

# check one of the stock
display(returns_df)
# Out:
#          Dates  AM_US_Equity  AROC_US_Equity  BOOM_US_Equity  CEIX_US_Equity  \
# 0   2023-10-31      0.000000        0.000000        0.000000        0.000000
# 1   2023-11-01      0.011475        0.007154        0.006908       -0.100617
# 2   2023-11-02      0.024311        0.040253       -0.008443        0.049516
# 3   2023-11-03      0.024525        0.045524        0.010644        0.015346
# 4   2023-11-06     -0.002317        0.034833       -0.099526       -0.001021
# ..         ...           ...             ...             ...             ...
# 259 2024-10-28      0.000667        0.012929        0.041206        0.011924
# 260 2024-10-29     -0.008661        0.005400       -0.010618        0.014567
# 261 2024-10-30      0.000000       -0.008789       -0.020488        0.009419
# 262 2024-10-31      0.008065       -0.007389        0.006972       -0.006523
# 263 2024-11-01     -0.042000       -0.006452       -0.001978        0.011490
#
#      CHX_US_Equity  CIVI_US_Equity  CLB_US_Equity  CNX_US_Equity  \
# 0         0.000000        0.000000       0.000000       0.000000
# 1         0.010830        0.010584      -0.004647       0.020197
# 2        -0.016883       -0.009148      -0.018674       0.005985
# 3         0.034016        0.031710       0.010942       0.018764
# 4        -0.000639       -0.001945      -0.006118       0.004043
# ..             ...             ...            ...            ...
# 259       0.009990       -0.001968       0.025871      -0.016935
# 260      -0.008186       -0.028594      -0.012867      -0.037189
# 261      -0.022696       -0.013601       0.016684      -0.004544
# 262      -0.006334        0.009261      -0.011282       0.001712
# 263      -0.000708       -0.005098      -0.019710      -0.030760
#
#      CPE_US_Equity  ...  PUMP_US_Equity  RES_US_Equity  REX_US_Equity  \
# 0         0.000000  ...        0.000000       0.000000       0.000000
# 1         0.002146  ...        0.003831      -0.008343       0.007688
# 2        -0.014726  ...        0.000000      -0.019231      -0.012891
# 3         0.007609  ...       -0.034351       0.011029       0.011461
# 4        -0.022654  ...        0.009881      -0.006061       0.007115
# ..             ...  ...             ...            ...            ...
# 259       0.000000  ...        0.021080      -0.005000      -0.002213
# 260       0.000000  ...       -0.024516      -0.035176       0.014637
# 261       0.000000  ...       -0.002646       0.005208      -0.020765
# 262       0.000000  ...       -0.043767      -0.008636       0.002455
# 263       0.000000  ...       -0.041609      -0.010453      -0.004008
#
#      RRC_US_Equity  SLCA_US_Equity  SM_US_Equity  SWN_US_Equity  \
# 0         0.000000        0.000000      0.000000       0.000000
# 1         0.035838       -0.017901      0.012557       0.009915
# 2         0.023717       -0.011599     -0.018601       0.004208
# 3         0.017989        0.017603      0.039424       0.027933
# 4        -0.003213       -0.015651     -0.016047       0.025815
# ..             ...             ...           ...            ...
# 259      -0.003499        0.000000      0.018029       0.000000
# 260      -0.011171        0.000000     -0.034959       0.000000
# 261       0.000646        0.000000     -0.003575       0.000000
# 262       0.015806        0.000000      0.016503       0.000000
# 263      -0.046364        0.000000     -0.012471       0.000000
#
#      TALO_US_Equity  TRGP_US_Equity  VTOL_US_Equity
# 0          0.000000        0.000000        0.000000
# 1          0.011089        0.000120        0.001916
# 2         -0.029677        0.006459       -0.003443
# 3          0.037899        0.072490        0.097889
# 4         -0.009609       -0.023601        0.031119
# ..              ...             ...             ...
# 259        0.017476       -0.015483        0.003807
# 260       -0.037214       -0.007472       -0.011960
# 261       -0.016848       -0.001882        0.005905
# 262        0.028226        0.013503       -0.011154
# 263        0.001961        0.001980       -0.015435
#
# [264 rows x 33 columns]

# %%
# calculate the covariance matrix and correlation matrix
numeric_returns_df = returns_df.drop(columns=['Dates'])
cov_matrix = numeric_returns_df.cov()
print("Covariance Matrix:")
print(cov_matrix)

corr_matrix = numeric_returns_df.corr()
print("Correlation Matrix:")
print(corr_matrix)
# Out:
# Covariance Matrix:
#                 AM_US_Equity  AROC_US_Equity  BOOM_US_Equity  CEIX_US_Equity  \
# AM_US_Equity        0.000154        0.000143        0.000069        0.000055
# AROC_US_Equity      0.000143        0.000391        0.000160        0.000146
# BOOM_US_Equity      0.000069        0.000160        0.001056        0.000113
# CEIX_US_Equity      0.000055        0.000146        0.000113        0.000650
# CHX_US_Equity       0.000090        0.000208        0.000229        0.000118
# CIVI_US_Equity      0.000114        0.000205        0.000152        0.000156
# CLB_US_Equity       0.000107        0.000198        0.000324        0.000233
# CNX_US_Equity       0.000103        0.000150        0.000080        0.000137
# CPE_US_Equity       0.000044        0.000064        0.000111        0.000078
# DTM_US_Equity       0.000090        0.000103        0.000037        0.000068
# ETRN_US_Equity      0.000068        0.000080        0.000049        0.000090
# HLX_US_Equity       0.000112        0.000249        0.000275        0.000209
# HP_US_Equity        0.000089        0.000210        0.000233        0.000162
# LPG_US_Equity       0.000095        0.000163        0.000153        0.000186
# MTDR_US_Equity      0.000116        0.000231        0.000196        0.000169
# MUR_US_Equity       0.000090        0.000184        0.000196        0.000153
# NOV_US_Equity       0.000093        0.000218        0.000256        0.000179
# OII_US_Equity       0.000119        0.000268        0.000319        0.000251
# OIS_US_Equity       0.000101        0.000227        0.000348        0.000253
# PARR_US_Equity      0.000086        0.000181        0.000284        0.000156
# PBF_US_Equity       0.000066        0.000151        0.000242        0.000187
# PTEN_US_Equity      0.000129        0.000236        0.000257        0.000186
# PUMP_US_Equity      0.000099        0.000222        0.000241        0.000174
# RES_US_Equity       0.000089        0.000202        0.000260        0.000139
# REX_US_Equity       0.000116        0.000192        0.000266        0.000210
# RRC_US_Equity       0.000121        0.000176        0.000052        0.000166
# SLCA_US_Equity      0.000043        0.000080        0.000118        0.000085
# SM_US_Equity        0.000129        0.000248        0.000186        0.000213
# SWN_US_Equity       0.000089        0.000145        0.000091        0.000140
# TALO_US_Equity      0.000146        0.000246        0.000250        0.000189
# TRGP_US_Equity      0.000104        0.000143        0.000060        0.000085
# VTOL_US_Equity      0.000103        0.000218        0.000206        0.000139
#
#                 CHX_US_Equity  CIVI_US_Equity  CLB_US_Equity  CNX_US_Equity  \
# AM_US_Equity         0.000090        0.000114       0.000107       0.000103
# AROC_US_Equity       0.000208        0.000205       0.000198       0.000150
# BOOM_US_Equity       0.000229        0.000152       0.000324       0.000080
# RES_US_Equity       0.513611       0.336098        0.430368        0.395722
# REX_US_Equity       0.292215       0.232638        0.295101        0.248279
# RRC_US_Equity       0.565380       0.726824        0.584807        0.497413
# SLCA_US_Equity      0.268797       0.225453        0.274753        0.225367
# SM_US_Equity        1.000000       0.454199        0.722004        0.582594
# SWN_US_Equity       0.454199       1.000000        0.439617        0.371231
# TALO_US_Equity      0.722004       0.439617        1.000000        0.545203
# TRGP_US_Equity      0.582594       0.371231        0.545203        1.000000
# VTOL_US_Equity      0.458770       0.348174        0.467168        0.439103
#
#                 VTOL_US_Equity
# AM_US_Equity          0.356756
# AROC_US_Equity        0.474529
# BOOM_US_Equity        0.272563
# CEIX_US_Equity        0.234611
# CHX_US_Equity         0.455075
# CIVI_US_Equity        0.552684
# CLB_US_Equity         0.523277
# CNX_US_Equity         0.400348
# CPE_US_Equity         0.307332
# DTM_US_Equity         0.335013
# ETRN_US_Equity        0.281913
# HLX_US_Equity         0.502578
# HP_US_Equity          0.486187
# LPG_US_Equity         0.349400
# MTDR_US_Equity        0.541035
# MUR_US_Equity         0.531981
# NOV_US_Equity         0.547357
# OII_US_Equity         0.543026
# OIS_US_Equity         0.365114
# PARR_US_Equity        0.381957
# PBF_US_Equity         0.291176
# PTEN_US_Equity        0.492504
# PUMP_US_Equity        0.517006
# RES_US_Equity         0.470348
# REX_US_Equity         0.248620
# RRC_US_Equity         0.410534
# SLCA_US_Equity        0.315131
# SM_US_Equity          0.458770
# SWN_US_Equity         0.348174
# TALO_US_Equity        0.467168
# TRGP_US_Equity        0.439103
# VTOL_US_Equity        1.000000
#
# [32 rows x 32 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 12))
sns.heatmap(
    corr_matrix, 
    annot=True, 
    cmap='coolwarm',        
    center=0,             
    fmt=".2f",            
    annot_kws={"size": 7} 
)

plt.title("Stocks Correlation Heatmap")
plt.show()

# %%
# Calculate top 10 stocks correlation
top_10_stocks = rank_df['Stock'][0:10]
top_10_corr = corr_matrix.loc[top_10_stocks, top_10_stocks]
# Display top 10 stocks correlation with one hot encoding
plt.figure(figsize=(10, 8))
sns.heatmap(
    top_10_corr, 
    annot=True, 
    cmap='coolwarm',        
    center=0,             
    fmt=".2f",            
    annot_kws={"size": 7} 
)
plt.title("TOP 10 Stocks Correlation Heatmap")
plt.show()

# %%
top_10_stocks = rank_df['Stock'][0:10]
top_10_corr = corr_matrix.loc[top_10_stocks, top_10_stocks]

# 从 returns_df 中获取这些股票的收益率数据
top_10_returns = returns_df[['Dates'] + list(top_10_stocks)]
display(top_10_returns)
# 计算前10只股票的平均收益率和协方差矩阵
expected_returns = top_10_returns.mean()  # 每只股票的预期收益
cov_matrix = top_10_returns.cov()         # 前10只股票的协方差矩阵
# Out:
#          Dates  PARR_US_Equity  PBF_US_Equity  MUR_US_Equity  CEIX_US_Equity  \
# 0   2023-10-31        0.000000       0.000000       0.000000        0.000000
# 1   2023-11-01        0.013276       0.031915      -0.001113       -0.100617
# 2   2023-11-02        0.005484       0.014096      -0.001337        0.049516
# 3   2023-11-03       -0.001818      -0.015768       0.029681        0.015346
# 4   2023-11-06       -0.013661      -0.030565      -0.004768       -0.001021
# ..         ...             ...            ...            ...             ...
# 259 2024-10-28        0.000000       0.010361       0.011416        0.011924
# 260 2024-10-29        0.016043      -0.018024      -0.028066        0.014567
# 261 2024-10-30       -0.076023      -0.079747      -0.019774        0.009419
# 262 2024-10-31       -0.007595      -0.008597       0.007045       -0.006523
# 263 2024-11-01       -0.014668      -0.010753       0.000954        0.011490
#
#      LPG_US_Equity  SM_US_Equity  CIVI_US_Equity  MTDR_US_Equity  \
# 0         0.000000      0.000000        0.000000        0.000000
# 1         0.052684      0.012557        0.010584        0.024581
# 2         0.087582     -0.018601       -0.009148       -0.012644
# 3         0.115617      0.039424        0.031710        0.037925
# 4        -0.018561     -0.016047       -0.001945       -0.012022
# ..             ...           ...             ...             ...
# 259       0.021732      0.018029       -0.001968       -0.010878
# 260      -0.009024     -0.034959       -0.028594       -0.022188
# 261      -0.013008     -0.003575       -0.013601       -0.003749
# 262      -0.025371      0.016503        0.009261        0.024361
# 263      -0.024679     -0.012471       -0.005098        0.007541
#
#      RES_US_Equity  HP_US_Equity
# 0         0.000000      0.000000
# 1        -0.008343      0.006102
# 2        -0.019231     -0.007329
# 3         0.011029      0.046334
# 4        -0.006061      0.006326
# ..             ...           ...
# 259      -0.005000      0.014710
# 260      -0.035176     -0.022615
# 261       0.005208     -0.011866
# 262      -0.008636      0.018313
# 263      -0.010453     -0.009434
#
# [264 rows x 11 columns]

# %% [markdown]
# ## Visualize functions

# %%
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
def plot_returns_over_time(best_combination, top_returns_df):
    """
    绘制最佳组合股票的时间序列图。
    
    参数:
    - best_combination: 选择的最佳组合的股票列表。
    - top_returns_df: 包含所有股票收益率的 DataFrame，需包含 'Dates' 列。
    """
    # 从 top_returns_df 提取最佳组合的 returns 数据，确保包含 Dates 列
    best_combination_returns = top_returns_df[['Dates'] + list(best_combination)].set_index('Dates')

    # 创建图形
    plt.figure(figsize=(15, 6))

    # 为每只股票绘制 returns 时间序列曲线
    for stock in best_combination_returns.columns:
        plt.plot(best_combination_returns.index, best_combination_returns[stock], label=stock)

    # 设置横坐标格式为月份
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())  # 每个月显示一个刻度

    # 添加图例和标题
    plt.title("Returns Over Time for Selected Stocks in Best Combination")
    plt.xlabel("Time")
    plt.ylabel("Returns")
    plt.legend()
    plt.grid(True)

    # 显示图形
    plt.show()

# %%
def plot_portfolio_returns_and_volatility(best_combination, top_returns_df, best_weights, window=20):
    """
    绘制组合的每日收益率和滚动波动率时间序列图。
    
    参数:
    - daily_returns: DataFrame，包含组合中各个股票的每日收益率。
    - weights: 数组，最佳组合的权重。
    - window: int，滚动窗口的大小（默认为20天）。
    """
    best_combination_returns = top_returns_df[['Dates'] + list(best_combination)].set_index('Dates')
    # 计算每日组合收益率（按行加权求和）
    portfolio_daily_returns = best_combination_returns.dot(best_weights)
    # 计算组合的滚动波动率
    rolling_volatility = portfolio_daily_returns.rolling(window=window).std()

    # 创建图形
    plt.figure(figsize=(15, 8))

    # 绘制每日收益率曲线
    plt.subplot(2, 1, 1)
    plt.plot(portfolio_daily_returns.index, portfolio_daily_returns, label='Portfolio Daily Returns', color='blue')
    plt.title("Portfolio Daily Returns")
    plt.xlabel("Date")
    plt.ylabel("Returns")
    plt.legend()
    plt.grid(True)
    # 设置横坐标格式为月份
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

    # 绘制滚动波动率曲线
    plt.subplot(2, 1, 2)
    plt.plot(rolling_volatility.index, rolling_volatility, label=f'{window}-Day Rolling Volatility', color='red')
    plt.title(f"Portfolio {window}-Day Rolling Volatility")
    plt.xlabel("Date")
    plt.ylabel("Volatility")
    plt.legend()
    plt.grid(True)
    # 设置横坐标格式为月份
    plt.gca().xaxis.set_major_formatter(DateFormatter('%Y-%m'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

    # 显示图形
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Based on volatility, we calculate the optimal weights for the selected stocks.

# %%
# 初始化变量以记录最佳组合和最小波动率
min_volatility = np.inf
best_combination = None
best_weights = None
best_corr_matrix = None

# 定义目标函数：最小化投资组合的波动率（标准差）
def portfolio_volatility(weights, cov_matrix):
    return np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))

# 定义约束：所有权重的和为1
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

# 定义边界：每只股票的权重在0到1之间
bounds = tuple((0, 1) for _ in range(len(top_10_stocks)))


# 遍历从5到10只股票的所有组合
for r in range(5, 11):
    for combination in itertools.combinations(top_10_stocks, r):
        # 选取组合的收益率和协方差矩阵
        comb_returns = expected_returns[list(combination)]
        comb_cov_matrix = cov_matrix.loc[list(combination), list(combination)]
        comb_corr_matrix = comb_cov_matrix.corr()  # 计算该组合的相关矩阵
        
        # 初始权重均分
        initial_weights = np.array([1 / r] * r)
        
        # 优化权重，最小化组合的波动率
        result = minimize(portfolio_volatility, initial_weights, args=(comb_cov_matrix,), 
                          method='SLSQP', bounds=tuple((0.1, 0.5) for _ in range(r)), constraints=constraints)
        
        # 检查优化结果
        if result.success:
            comb_volatility = portfolio_volatility(result.x, comb_cov_matrix)
            # 记录波动率最小的组合
            if comb_volatility < min_volatility:
                min_volatility = comb_volatility
                best_combination = combination
                best_weights = result.x
                best_corr_matrix = comb_corr_matrix 

# 输出最佳组合及其权重
# 打印最佳组合、权重、最大Sharpe比率、预期收益和波动率
print("Optimal Portfolio Allocation:")
for stock, weight in zip(best_combination, best_weights):
    print(f"{stock}: {weight:.2f}")
print("Minimum portfolio volatility:", min_volatility)
# 输出最佳组合的相关矩阵
# print("\nCorrelation matrix for the best combination:")
# print(best_corr_matrix)
# Out:
# Optimal Portfolio Allocation:
# PARR_US_Equity: 0.11
# MUR_US_Equity: 0.49
# CEIX_US_Equity: 0.15
# LPG_US_Equity: 0.14
# RES_US_Equity: 0.10
# Minimum portfolio volatility: 0.015300020920731523

# %% [markdown]
# ## Visualize the results for volatility optimization

# %%
plot_returns_over_time(best_combination, top_10_returns)

# %%
plot_portfolio_returns_and_volatility(best_combination, top_10_returns, best_weights)

# %% [markdown]
# ## Based on Shape Ratio, we calculate the optimal weights for the selected stocks.

# %%
# 去除 'Dates' 列，仅选择数值列来计算预期收益和协方差矩阵
numeric_columns = top_10_returns.columns.difference(['Dates'])

# 计算前10只股票的平均收益率和协方差矩阵
expected_returns = top_10_returns[numeric_columns].mean()  # 每只股票的预期收益
cov_matrix = top_10_returns[numeric_columns].cov()         # 前10只股票的协方差矩阵
# 定义无风险利率
risk_free_rate = 0.02

# 定义负的Sharpe比率（因为要最小化目标函数）
def neg_sharpe_ratio(weights, expected_returns, cov_matrix, risk_free_rate):
    portfolio_return = np.dot(weights, expected_returns)
    portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights)))
    sharpe_ratio = (portfolio_return - risk_free_rate) / portfolio_volatility
    return -sharpe_ratio  # 优化的是最小值，所以返回负的Sharpe比率

# 约束条件：所有权重之和为1
constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})

# 初始化变量以记录最佳组合、最高Sharpe比率和最佳权重
max_sharpe_ratio = -np.inf
best_combination = None
best_weights = None

# 遍历从5到10只股票的所有组合
for r in range(5, 11):
    for combination in itertools.combinations(top_10_stocks, r):
        comb_returns = expected_returns[list(combination)]
        comb_cov_matrix = cov_matrix.loc[list(combination), list(combination)]
        
        # 定义每个组合的初始权重
        initial_weights = np.array([1 / r] * r)
        
        # 设置权重边界，确保权重在0.05到1之间
        bounds = tuple((0.1, 0.5) for _ in range(r))
        
        # 优化权重，最大化Sharpe比率
        result = minimize(
            neg_sharpe_ratio,
            initial_weights,
            args=(comb_returns, comb_cov_matrix, risk_free_rate),
            method='SLSQP',
            bounds=bounds,
            constraints=constraints
        )
        
        # 检查优化结果
        if result.success:
            sharpe_ratio = -result.fun
            # 如果当前组合的Sharpe比率更高，则更新最佳组合
            if sharpe_ratio > max_sharpe_ratio:
                max_sharpe_ratio = sharpe_ratio
                best_combination = combination
                best_weights = np.round(result.x, 2)

# 计算最佳组合的收益率和波动率
optimal_portfolio_return = np.dot(best_weights, expected_returns[list(best_combination)])
optimal_portfolio_volatility = np.sqrt(np.dot(best_weights.T, np.dot(cov_matrix.loc[list(best_combination), list(best_combination)], best_weights)))

# 打印最佳组合、权重、最大Sharpe比率、预期收益和波动率
print("Optimal Portfolio Allocation:")
for stock, weight in zip(best_combination, best_weights):
    print(f"{stock}: {weight:.2f}")

print("Maximum Sharpe Ratio:", max_sharpe_ratio)
print("Optimal Portfolio Expected Return:", optimal_portfolio_return)
print("Optimal Portfolio Volatility:", optimal_portfolio_volatility)
# Out:
# Optimal Portfolio Allocation:
# SM_US_Equity: 0.50
# CIVI_US_Equity: 0.10
# MTDR_US_Equity: 0.10
# RES_US_Equity: 0.10
# HP_US_Equity: 0.20
# Maximum Sharpe Ratio: -1.0129413387251405
# Optimal Portfolio Expected Return: -0.0001309130329375487
# Optimal Portfolio Volatility: 0.0198737204844199

# %% [markdown]
# ## Visualize the results for Sharpe Ratio optimization

# %%
plot_returns_over_time(best_combination, top_10_returns)

# %%
plot_portfolio_returns_and_volatility(best_combination, top_10_returns, best_weights)
